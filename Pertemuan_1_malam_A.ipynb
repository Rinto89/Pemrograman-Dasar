# %% [markdown]
# <a href="https://colab.research.google.com/github/Rinto89/Pemrograman-Dasar/blob/main/Pertemuan_1_malam_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = "Rinto"
umur = 30
jurusan = "Rpe"
semester = 3
matakuliah = 'Pemograman Dasar'
status_lulus = False
alamat = "Kav_kamboja"



print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
print (alamat)
# Out:
# Rinto
# 30
# Rpe
# 3
# Pemograman Dasar
# False
# Kav_kamboja
